# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd
df =pd.read_csv('/Users/restynasimbwa/python/pandas/weather_data 2.csv')
df
# Out:
#             Location            Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1          San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2          San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3       Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4        San Antonio  2024-04-29 13:23:51      39.808213     72.899908
# ...              ...                  ...            ...           ...
# 999995        Dallas  2024-01-01 20:29:48      23.416877     37.705024
# 999996   San Antonio  2024-01-20 15:59:48       6.759080     40.731036
# 999997      New York  2024-04-14 08:30:09      15.664465     62.201884
# 999998       Chicago  2024-05-12 20:10:43      18.999994     63.703245
# 999999      New York  2024-04-16 16:11:52      10.725351     43.804584
#
#         Precipitation_mm  Wind_Speed_kmh
# 0               4.020119        8.233540
# ...

# %%
weather_data1 = pd.DataFrame({
    'day':['1/9/2017','1/10/2017','1/11/2017','1/12/2017','1/13/2017','1/14/2017'],
    'temperature': [90,45,28,19,46,56],
    'windspeed': [9,4,2,9,9,3],
    'event': ['Rain', 'Sunny', 'Snow', 'Snow', 'Rain', 'Sunny']    
})
weather_data1
# Out:
#          day  temperature  windspeed  event
# 0   1/9/2017           90          9   Rain
# 1  1/10/2017           45          4  Sunny
# 2  1/11/2017           28          2   Snow
# 3  1/12/2017           19          9   Snow
# 4  1/13/2017           46          9   Rain
# 5  1/14/2017           56          3  Sunny

# %%
weather_data2 = pd.DataFrame({
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [34,56,34,13,34,55],
    'windspeed': [6,8,6,9,2,3],
    'event': ['Rain', 'Sunny', 'Snow', 'Snow', 'Rain', 'Sunny' ]    
})


weather_data2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           34          6   Rain
# 1  1/2/2017           56          8  Sunny
# 2  1/3/2017           34          6   Snow
# 3  1/4/2017           13          9   Snow
# 4  1/5/2017           34          2   Rain
# 5  1/6/2017           55          3  Sunny

# %%
pd.concat([weather_data1, weather_data2])
# Out:
#          day  temperature  windspeed  event
# 0   1/9/2017           90          9   Rain
# 1  1/10/2017           45          4  Sunny
# 2  1/11/2017           28          2   Snow
# 3  1/12/2017           19          9   Snow
# 4  1/13/2017           46          9   Rain
# 5  1/14/2017           56          3  Sunny
# 0   1/1/2017           34          6   Rain
# 1   1/2/2017           56          8  Sunny
# 2   1/3/2017           34          6   Snow
# 3   1/4/2017           13          9   Snow
# 4   1/5/2017           34          2   Rain
# 5   1/6/2017           55          3  Sunny

# %%
pd.concat([weather_data1, weather_data2], ignore_index=True) # Ignore index
# Out:
#           day  temperature  windspeed  event
# 0    1/9/2017           90          9   Rain
# 1   1/10/2017           45          4  Sunny
# 2   1/11/2017           28          2   Snow
# 3   1/12/2017           19          9   Snow
# 4   1/13/2017           46          9   Rain
# 5   1/14/2017           56          3  Sunny
# 6    1/1/2017           34          6   Rain
# 7    1/2/2017           56          8  Sunny
# 8    1/3/2017           34          6   Snow
# 9    1/4/2017           13          9   Snow
# 10   1/5/2017           34          2   Rain
# 11   1/6/2017           55          3  Sunny

# %%
df = pd.concat([weather_data1, weather_data2],keys=['weather1' , 'weather2']) # Associate a key with each of the dataframes
df
# Out:
#                   day  temperature  windspeed  event
# weather1 0   1/9/2017           90          9   Rain
#          1  1/10/2017           45          4  Sunny
#          2  1/11/2017           28          2   Snow
#          3  1/12/2017           19          9   Snow
#          4  1/13/2017           46          9   Rain
#          5  1/14/2017           56          3  Sunny
# weather2 0   1/1/2017           34          6   Rain
#          1   1/2/2017           56          8  Sunny
#          2   1/3/2017           34          6   Snow
#          3   1/4/2017           13          9   Snow
#          4   1/5/2017           34          2   Rain
#          5   1/6/2017           55          3  Sunny

# %%
df.loc["weather1"] # retrieve a specific dataframe
# Out:
#          day  temperature  windspeed  event
# 0   1/9/2017           90          9   Rain
# 1  1/10/2017           45          4  Sunny
# 2  1/11/2017           28          2   Snow
# 3  1/12/2017           19          9   Snow
# 4  1/13/2017           46          9   Rain
# 5  1/14/2017           56          3  Sunny
