# %%
import pandas as pd

df = pd.read_csv('/Users/restynasimbwa/python/pandas/weather_missing_values.csv')
df
# Out:
#             Location      Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego  1/14/24 21:12      10.683001     41.195754
# 1          San Diego  5/17/24 15:22       8.734140           NaN
# 2          San Diego   5/11/24 9:30      11.632436     38.820175
# 3       Philadelphia  2/26/24 17:32            NaN     54.074474
# 4        San Antonio  4/29/24 13:23      39.808213     72.899908
# ...              ...            ...            ...           ...
# 999995        Dallas   1/1/24 20:29      23.416877     37.705024
# 999996   San Antonio  1/20/24 15:59       6.759080     40.731036
# 999997      New York   4/14/24 8:30      15.664465     62.201884
# 999998       Chicago  5/12/24 20:10      18.999994     63.703245
# 999999      New York  4/16/24 16:11      10.725351     43.804584
#
#         Precipitation_mm  Wind_Speed_kmh
# 0               4.020119             NaN
# 1               9.111623       27.715161
# 2                    NaN       28.732951
# ...

# %%
g= df.groupby('Location')
g

# %%
for location , df_location in g:
    print(location)
    print(df_location)
# Out:
# Chicago
#        Location      Date_Time  Temperature_C  Humidity_pct  Precipitation_mm  \
# 17      Chicago    1/6/24 2:59      26.786811     31.513614          0.496024
# 32      Chicago   4/16/24 0:07      17.587820     32.817923          0.128803
# 38      Chicago    4/1/24 3:12      -2.562660     30.356593          2.624328
# 45      Chicago   4/3/24 12:07       7.166150     50.377273          4.669553
# 47      Chicago   4/5/24 13:22      38.386233     74.049712          6.792913
# ...         ...            ...            ...           ...               ...
# 999954  Chicago   1/22/24 1:18      31.870160     71.849950          0.842965
# 999960  Chicago  1/31/24 15:53      -9.061359     72.270546          6.224749
# 999973  Chicago   1/25/24 1:43      16.432551     41.331437          4.395345
# 999983  Chicago    3/2/24 7:20      -6.500893     49.713982          3.050012
# 999998  Chicago  5/12/24 20:10      18.999994     63.703245          4.294325
#
#         Wind_Speed_kmh
# ...

# %%
g.get_group('Chicago')
# Out:
#        Location      Date_Time  Temperature_C  Humidity_pct  Precipitation_mm  \
# 17      Chicago    1/6/24 2:59      26.786811     31.513614          0.496024
# 32      Chicago   4/16/24 0:07      17.587820     32.817923          0.128803
# 38      Chicago    4/1/24 3:12      -2.562660     30.356593          2.624328
# 45      Chicago   4/3/24 12:07       7.166150     50.377273          4.669553
# 47      Chicago   4/5/24 13:22      38.386233     74.049712          6.792913
# ...         ...            ...            ...           ...               ...
# 999954  Chicago   1/22/24 1:18      31.870160     71.849950          0.842965
# 999960  Chicago  1/31/24 15:53      -9.061359     72.270546          6.224749
# 999973  Chicago   1/25/24 1:43      16.432551     41.331437          4.395345
# 999983  Chicago    3/2/24 7:20      -6.500893     49.713982          3.050012
# 999998  Chicago  5/12/24 20:10      18.999994     63.703245          4.294325
#
#         Wind_Speed_kmh
# ...

# %%
g.max()
# Out:
#                 Date_Time  Temperature_C  Humidity_pct  Precipitation_mm  \
# Location
# Chicago       5/9/24 9:56      39.998561     89.998857          9.999889
# Dallas        5/9/24 9:56      39.998804     89.999929          9.999968
# Houston       5/9/24 9:53      39.998913     89.999082          9.999921
# Los Angeles   5/9/24 9:59      39.999592     89.998014          9.999522
# New York      5/9/24 9:58      39.999801     89.999880          9.999992
# Philadelphia  5/9/24 9:58      39.999642     89.999332          9.999944
# Phoenix       5/9/24 9:57      39.998889     89.999666         14.971583
# San Antonio   5/9/24 9:52      39.998343     89.999637          9.999734
# San Diego     5/9/24 9:58      39.999692     89.998941          9.999716
# San Jose      5/9/24 9:58      39.999015     89.999977          9.999830
#
#               Wind_Speed_kmh
# Location
# Chicago            29.999889
# Dallas             29.999971
# Houston            29.999948
# ...

# %%
#g.mean()
# %matplotlib inline
g.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 #g.mean()
# ----> 2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 g.plot()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
