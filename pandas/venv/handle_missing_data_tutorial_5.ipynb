# %%
import pandas as pd
from datetime import datetime
dateformat = lambda dates: datetime.strptime(dates, '%Y-%m-%d %H:%M:%S') 
df = pd.read_csv('/Users/restynasimbwa/python/pandas/weather_missing_values.csv', parse_dates=["Date_Time"],date_format=dateformat)
df
#2024-01-14 21:12:46
# Out:
#             Location      Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego  1/14/24 21:12      10.683001     41.195754
# 1          San Diego  5/17/24 15:22       8.734140           NaN
# 2          San Diego   5/11/24 9:30      11.632436     38.820175
# 3       Philadelphia  2/26/24 17:32            NaN     54.074474
# 4        San Antonio  4/29/24 13:23      39.808213     72.899908
# ...              ...            ...            ...           ...
# 999995        Dallas   1/1/24 20:29      23.416877     37.705024
# 999996   San Antonio  1/20/24 15:59       6.759080     40.731036
# 999997      New York   4/14/24 8:30      15.664465     62.201884
# 999998       Chicago  5/12/24 20:10      18.999994     63.703245
# 999999      New York  4/16/24 16:11      10.725351     43.804584
#
#         Precipitation_mm  Wind_Speed_kmh
# 0               4.020119             NaN
# 1               9.111623       27.715161
# 2                    NaN       28.732951
# ...

# %%
type(df.Date_Time[0])
# Out:
# str

# %%
df.set_index('Date_Time', inplace=True)
df
# Out:
#                    Location  Temperature_C  Humidity_pct  Precipitation_mm  \
# Date_Time
# 1/14/24 21:12     San Diego      10.683001     41.195754          4.020119
# 5/17/24 15:22     San Diego       8.734140           NaN          9.111623
# 5/11/24 9:30      San Diego      11.632436     38.820175               NaN
# 2/26/24 17:32  Philadelphia            NaN     54.074474          3.183720
# 4/29/24 13:23   San Antonio      39.808213     72.899908          9.598282
# ...                     ...            ...           ...               ...
# 1/1/24 20:29         Dallas      23.416877     37.705024          3.819833
# 1/20/24 15:59   San Antonio       6.759080     40.731036          8.182785
# 4/14/24 8:30       New York      15.664465     62.201884          3.987558
# 5/12/24 20:10       Chicago      18.999994     63.703245          4.294325
# 4/16/24 16:11      New York      10.725351     43.804584          1.883292
#
#                Wind_Speed_kmh
# Date_Time
# ...

# %%
new_df = df.fillna(0)
new_df
# Out:
#                    Location  Temperature_C  Humidity_pct  Precipitation_mm  \
# Date_Time
# 1/14/24 21:12     San Diego      10.683001     41.195754          4.020119
# 5/17/24 15:22     San Diego       8.734140      0.000000          9.111623
# 5/11/24 9:30      San Diego      11.632436     38.820175          0.000000
# 2/26/24 17:32  Philadelphia       0.000000     54.074474          3.183720
# 4/29/24 13:23   San Antonio      39.808213     72.899908          9.598282
# ...                     ...            ...           ...               ...
# 1/1/24 20:29         Dallas      23.416877     37.705024          3.819833
# 1/20/24 15:59   San Antonio       6.759080     40.731036          8.182785
# 4/14/24 8:30       New York      15.664465     62.201884          3.987558
# 5/12/24 20:10       Chicago      18.999994     63.703245          4.294325
# 4/16/24 16:11      New York      10.725351     43.804584          1.883292
#
#                Wind_Speed_kmh
# Date_Time
# ...

# %%
new_df2 = df.fillna({
    'Temperature_C':0,
    'Humidity_pct':0,
    'Humidity_pct':'test'
    
})
new_df2
# Out:
#                    Location  Temperature_C Humidity_pct  Precipitation_mm  \
# Date_Time
# 1/14/24 21:12     San Diego      10.683001    41.195754          4.020119
# 5/17/24 15:22     San Diego       8.734140         test          9.111623
# 5/11/24 9:30      San Diego      11.632436    38.820175               NaN
# 2/26/24 17:32  Philadelphia       0.000000    54.074474          3.183720
# 4/29/24 13:23   San Antonio      39.808213    72.899908          9.598282
# ...                     ...            ...          ...               ...
# 1/1/24 20:29         Dallas      23.416877    37.705024          3.819833
# 1/20/24 15:59   San Antonio       6.759080    40.731036          8.182785
# 4/14/24 8:30       New York      15.664465    62.201884          3.987558
# 5/12/24 20:10       Chicago      18.999994    63.703245          4.294325
# 4/16/24 16:11      New York      10.725351    43.804584          1.883292
#
#                Wind_Speed_kmh
# Date_Time
# ...

# %%
#new_df3 = df.fillna(method='ffill') # ffill means carry forward previous day's value
new_df3 = df.ffill()
new_df3
# Out:
#                    Location  Temperature_C  Humidity_pct  Precipitation_mm  \
# Date_Time
# 1/14/24 21:12     San Diego      10.683001     41.195754          4.020119
# 5/17/24 15:22     San Diego       8.734140     41.195754          9.111623
# 5/11/24 9:30      San Diego      11.632436     38.820175          9.111623
# 2/26/24 17:32  Philadelphia      11.632436     54.074474          3.183720
# 4/29/24 13:23   San Antonio      39.808213     72.899908          9.598282
# ...                     ...            ...           ...               ...
# 1/1/24 20:29         Dallas      23.416877     37.705024          3.819833
# 1/20/24 15:59   San Antonio       6.759080     40.731036          8.182785
# 4/14/24 8:30       New York      15.664465     62.201884          3.987558
# 5/12/24 20:10       Chicago      18.999994     63.703245          4.294325
# 4/16/24 16:11      New York      10.725351     43.804584          1.883292
#
#                Wind_Speed_kmh
# Date_Time
# ...

# %%
#df.infer_objects(copy=False)
new_df4 = df.interpolate(method='time') # use medium of the previous and the next value,  considers time when determing the value of the empty field
new_df4
# Out:
# /var/folders/sp/py6g1cy16yx2440xmk8nbxjh0000gn/T/ipykernel_69648/1940710952.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df4 = df.interpolate() # use medium of the previous and the next value
#                    Location  Temperature_C  Humidity_pct  Precipitation_mm  \
# Date_Time
# 1/14/24 21:12     San Diego      10.683001     41.195754          4.020119
# 5/17/24 15:22     San Diego       8.734140     40.007964          9.111623
# 5/11/24 9:30      San Diego      11.632436     38.820175          6.147672
# 2/26/24 17:32  Philadelphia      25.720325     54.074474          3.183720
# 4/29/24 13:23   San Antonio      39.808213     72.899908          9.598282
# ...                     ...            ...           ...               ...
# 1/1/24 20:29         Dallas      23.416877     37.705024          3.819833
# ...

# %%
new_df5 = df.dropna() # delete data with empty values df.dropna(how="all") only delete if the every thing is empty
new_df5
# Out:
#                   Location  Temperature_C  Humidity_pct  Precipitation_mm  \
# Date_Time
# 4/29/24 13:23  San Antonio      39.808213     72.899908          9.598282
# 1/21/24 8:54     San Diego      27.341055     49.023236          9.166543
# 1/13/24 2:10      San Jose       1.881883     65.742325          0.221709
# 1/25/24 19:04     New York      -6.894766     30.804894          8.027624
# 3/29/24 5:20      New York       0.963545     38.819158          3.640129
# ...                    ...            ...           ...               ...
# 1/1/24 20:29        Dallas      23.416877     37.705024          3.819833
# 1/20/24 15:59  San Antonio       6.759080     40.731036          8.182785
# 4/14/24 8:30      New York      15.664465     62.201884          3.987558
# 5/12/24 20:10      Chicago      18.999994     63.703245          4.294325
# 4/16/24 16:11     New York      10.725351     43.804584          1.883292
#
#                Wind_Speed_kmh
# Date_Time
# ...

# %%
new_df6 = df.replace(['San Antonio','San Jose','New York'],[1,2,3])
new_df6
# Out:
#                    Location  Temperature_C  Humidity_pct  Precipitation_mm  \
# Date_Time
# 1/14/24 21:12     San Diego      10.683001     41.195754          4.020119
# 5/17/24 15:22     San Diego       8.734140           NaN          9.111623
# 5/11/24 9:30      San Diego      11.632436     38.820175               NaN
# 2/26/24 17:32  Philadelphia            NaN     54.074474          3.183720
# 4/29/24 13:23             1      39.808213     72.899908          9.598282
# ...                     ...            ...           ...               ...
# 1/1/24 20:29         Dallas      23.416877     37.705024          3.819833
# 1/20/24 15:59             1       6.759080     40.731036          8.182785
# 4/14/24 8:30              3      15.664465     62.201884          3.987558
# 5/12/24 20:10       Chicago      18.999994     63.703245          4.294325
# 4/16/24 16:11             3      10.725351     43.804584          1.883292
#
#                Wind_Speed_kmh
# Date_Time
# ...
